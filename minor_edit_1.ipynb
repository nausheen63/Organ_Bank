# %%
'''
Programe Name: Heal Hands

MEMBER 01: 
Name: Name: Dewashish Solanke


MEMBER 02:
Name: Nausheen Aftab


MEMBER 03:
Name : Sharwari Chadurkar

'''

from tkinter import *
from tkinter import messagebox as ms
import sqlite3
from tkinter import PhotoImage
from PIL import ImageTk,Image
import random

win = Tk()
win.title("H E A L   H A N D S ")
win.geometry("1450x750+30+30")

bill_no=StringVar()
x=random.randint(1000,9999)
bill_no.set(str(x))

#Database

#create a database or connect to one

conn = sqlite3.connect('User_Data.db')

#create cursor
c = conn.cursor()

'''
#create table
c.execute(""" CREATE TABLE user(
            first_name text,
            last_name text,
            city text,
            state text,
            zipcode integer)""")
'''
#commit changes
conn.commit()

n1=0
n2=0
n3=0
n4=0
n5=0
n6=0
n=0

#main Class
class main:
    def __init__(self,master):
    	# Window 
        self.master = master
        # Some Usefull variables
        self.username = StringVar()
        self.password = StringVar()
        self.n_username = StringVar()
        self.n_password = StringVar()
        #Create Widgets
        self.widgets()

    #Login Function
    def login(self):
    	#Establish Connection
        with sqlite3.connect('quit.db') as db:
            c = db.cursor()

        #Find user If there is any take proper action
        find_user = ('SELECT * FROM user WHERE username = ? and password = ?')
        c.execute(find_user,[(self.username.get()),(self.password.get())])
        result = c.fetchall()
        if result:
            self.logf.pack_forget()
            self.head['text'] = self.username.get() + '\n Loged In'
            self.head['pady'] = 150
        else:
            ms.showerror('Oops!','Username Not Found.')
            
    def new_user(self):
    	#Establish Connection
        with sqlite3.connect('quit.db') as db:
            c = db.cursor()

        #Find Existing username if any take proper action
        find_user = ('SELECT username FROM user WHERE username = ?')
        c.execute(find_user,[(self.n_username.get())])        
        if c.fetchall():
            ms.showerror('Error!','Username Taken Try a Diffrent One.')
        else:
            ms.showinfo('Success!','Account Created!')
            self.log()
        #Create New Account 
        insert = 'INSERT INTO user(username,password) VALUES(?,?)'
        c.execute(insert,[(self.n_username.get()),(self.n_password.get())])
        db.commit()

        #Frame Packing Methords
    def log(self):
        self.username.set('')
        self.password.set('')
        self.crf.pack_forget()
        self.head['text'] = 'LOGIN'
        self.logf.pack()
    def cr(self):
        self.n_username.set('')
        self.n_password.set('')
        self.logf.pack_forget()
        self.head['text'] = 'Create Account'
        self.crf.pack()
        
    #Draw Widgets
    def widgets(self):
   
        self.head=Label(win,text="Welcome to Heal Hands",relief=SUNKEN, fg="black", font=("Times",22) ,bg="yellow")
        self.head.place(x=40,y=10,width=500,height=50)
        self.head.pack()
        

        self.logf = Frame(self.master,padx =10,pady = 10)
        Label(self.logf,text = 'Username: ',font = ('',20),pady=5,padx=5).grid(sticky = W)
        Entry(self.logf,textvariable = self.username,bd = 5,font = ('',15)).grid(row=0,column=1)
        Label(self.logf,text = 'Password: ',font = ('',20),pady=5,padx=5).grid(sticky = W)
        Entry(self.logf,textvariable = self.password,bd = 5,font = ('',15),show = '*').grid(row=1,column=1)
        Button(self.logf,text = ' Login ',bd = 3 ,font = ('',15),padx=5,pady=5,command=self.login).grid()
        Button(self.logf,text = ' Create Account ',bd = 3 ,font = ('',15),padx=5,pady=5,command=self.cr).grid(row=2,column=1)
        self.logf.pack()
        
        self.crf = Frame(self.master,padx =10,pady = 10)
        Label(self.crf,text = 'Username: ',font = ('',20),pady=5,padx=5).grid(sticky = W)
        Entry(self.crf,textvariable = self.n_username,bd = 5,font = ('',15)).grid(row=0,column=1)
        Label(self.crf,text = 'Password: ',font = ('',20),pady=5,padx=5).grid(sticky = W)
        Entry(self.crf,textvariable = self.n_password,bd = 5,font = ('',15),show = '*').grid(row=1,column=1)
        Button(self.crf,text = 'Create Account',bd = 3 ,font = ('',15),padx=5,pady=5,command=self.new_user).grid()
        Button(self.crf,text = 'Go to Login',bd = 3 ,font = ('',15),padx=5,pady=5,command=self.log).grid(row=2,column=1)

def your_profile():
    global n1,b1,b7,n,p1,r1,q1

    btn1.destroy()
    btn2.destroy()
    btn3.destroy()
    btn4.destroy()
    btn5.destroy()
    btn6.destroy()
    lbl_img1.destroy()
    lbl_img2.destroy()
    lbl_img3.destroy()
    lbl_img4.destroy()
    lbl_img5.destroy()
    lbl_img6.destroy()
    lbl1.destroy()
    frm1.destroy()
    
def Book2():
    global n2,b2,b7,n,p2,r2,q2
    
    b2.delete(0,'end')
    n2=n2+1
    b2.insert('end',str(n2))
    r2="220.00"
    q2=n2*220
    p2="Hemoglobin -"
    n=n+1
    b7.delete(0,'end')
    b7.insert('end',str(n))
    
def Book3():
    global n3,b3,b7,n,p3,r3,q3
    
    b3.delete(0,'end')
    n3=n3+1
    b3.insert('end',str(n3))
    r3="327.00"
    q3=n3*327
    p3=" SpO2 Level - "
    n=n+1
    b7.delete(0,'end')
    b7.insert('end',str(n))
    
def Book4():
    global n4,b4,b7,n,p4,r4,q4
    
    b4.delete(0,'end')
    n4=n4+1
    b4.insert('end',str(n4))
    r4="120.00"
    q4=n4*120
    p4=" Sugar Level -"
    n=n+1
    b7.delete(0,'end')
    b7.insert('end',str(n))
    
def Book5():
    global n5,b5,b7,n,p5,r5,q5
    
    b5.delete(0,'end')
    n5=n5+1
    b5.insert('end',str(n5)) 
    r5="1159.00"
    q5=n5*1159
    p5=" RCBs -"
    n=n+1
    b7.delete(0,'end')
    b7.insert('end',str(n))
    
def Book6():
    global n6,b6,b7,n,p6,r6,q6
    
    b6.delete(0,'end')
    n6=n6+1
    b6.insert('end',str(n6))
    r6="170.00"
    q6=n6*170
    p6="Platelets -"
    n=n+1
    b7.delete(0,'end')
    b7.insert('end',str(n))
    
    
def admin():
    global admin_log,admin_button
    
        #Login button
    admin_button=Button(win,text="LOGIN",bg="maroon", fg="white",font=("Helvetica",16) ,bd=5,command=Books)
    admin_button.place(x=650,y=590,width=120,height=30)

            
    frame1.destroy()
    lbl_img.destroy()
    button1.destroy()
    button2.destroy()
    
    
def user():
    global user_log,user_button,frm0,image1,frm2,lbl3,txtfld1,txtfld2,lbl1,lbl2,lbl3,frm1,img0,lbl_img1,inp,text_lbl

        
    #opening screen
    frm0=Frame(win,bg="lavender",bd=7)
    frm0.place(x=0,y=0,width=1450,height=750)

    #inserting image
    image1 = Image.open("Picture1a.png")
    image1 = ImageTk.PhotoImage(image1)
    lbl_img1 = Label(image=img)
    lbl_img1.image = img
    lbl_img1.place(x=550,y=100)

    #title
    frm1=Frame(win,bg="black",bd=7)
    frm1.place(x=460,y=10,width=540,height=70)
    lbl1=Label(win,text="Welcome to Heal Hands",relief=SUNKEN, fg="black", font=("Times",22) ,bg="yellow")
    lbl1.place(x=480,y=20,width=500,height=50)

    #For user ID
    frm2=Frame(win,bg="steel blue",bd=5)
    frm2.place(x=490,y=450,width=500,height=200)
    lbl2=Label(win,text="Enter User ID:", fg="black", font=("Helvetica",16) ,bg="white")
    lbl2.place(x=520,y=470,width=150,height=30)
    txtfld1 = Entry(win,bg="white",fg="black", font=("Helvetica",16) ,bd=5)
    txtfld1.place(x=730,y=470,width=230,height=30)


    #For password
    lbl3=Label(win,text="Enter Password:", fg="black", font=("Helvetica",16) ,bg="white")
    lbl3.place(x=520,y=530,width=160,height=30)
    txtfld2 = Entry(win,bg="white",fg="black", font=("Helvetica",16) ,bd=5,show="*")
    txtfld2.place(x=730,y=530,width=230,height=30)
    
    #Login button
    user_button=Button(win,text="LOGIN",bg="maroon", fg="white",font=("Helvetica",16) ,bd=5,command=Books)
    user_button.place(x=650,y=590,width=120,height=30)



def Books():
    global txtfld1,txtfld2,lbl_img0,frm0,frm1,lbl1,frm2,lblfrm,lbl_img,btn10,lbl,bl1,b1,bl2,b2,bl3,b3,bl4,b4,bl5,b5,bl6,b6,bl7,b7,btn7,lbl_img1,lbl2,lblp1,btn1,lbl_img2,lbl2,lblp2,btn2,lbl_img3,lbl3,lblp3,btn3,lbl_img4,lbl4,lblp4,btn4,lbl_img5,lbl5,lblp5,btn5,lbl_img6,lbl6,lblp6,btn6
    
    
    frm0.destroy()
    lbl_img.destroy()
    frm1.destroy()
    lbl1.destroy()
    frm2.destroy()
    lbl2.destroy()
    txtfld1.destroy()
    lbl3.destroy()
    txtfld2.destroy()  
    
    img0 = Image.open("macbook-bg.png")
    img0 = ImageTk.PhotoImage(img0)
    lbl_img0 = Label(image=img0)
    lbl_img0.image = img0
    lbl_img0.place(x=250,y=0)
    
    frm0=Frame(win,bg="LightSkyBlue2",bd=7)
    frm0.place(x=0,y=0,width=300,height=750)
    
    #title
    frm1=Frame(win,bg="black",bd=7)
    frm1.place(x=643,y=10,width=340,height=70)
    lbl1=Label(win,text="HEAL HANDS", fg="black", font=("Helvetica",22) ,bg="Yellow")
    lbl1.place(x=660,y=20,width=300,height=50)
    
    #cart
    frm2=Frame(win,bg="pale violet red",bd=5)
    frm2.place(x=5,y=10,width=295,height=530)
    
    lblfrm=LabelFrame(win,text="R E P O R T")
    lblfrm.place(x=12,y=13,width=285,height=500)
    
    img1 = Image.open("report2.png")
    img = ImageTk.PhotoImage(img1)
    lbl_img = Label(image=img)
    lbl_img.image = img
    lbl_img.place(x=180,y=30)
    
    btn10=Button(win,text="Enter your Medical Report",bg="goldenrod3",fg="black",font=("Helvetica") ,bd=5)
    btn10.place(x=20,y=60,width=150,height=30)
    
    lbl=Label(win,text=" Enter your Medical Report ")
    lbl.place(x=20,y=60,width=150,height=30)
    
    bl1=Label(win,text=" Blood Group -")
    bl1.place(x=20,y=100)
    b1=Entry()
    b1.place(x=180,y=100,width=40,height=30)
    
    bl2=Label(win,text=" Hemoglobin -")
    bl2.place(x=20,y=150)
    b2=Entry()
    b2.place(x=180,y=150,width=40,height=30)
    
    bl3=Label(win,text=" SpO2 Level -")
    bl3.place(x=20,y=200)
    b3=Entry()
    b3.place(x=180,y=200,width=40,height=30)
    
    bl4=Label(win,text=" Sugar Level -")
    bl4.place(x=20,y=250)
    b4=Entry()
    b4.place(x=180,y=250,width=40,height=30)
    
    bl5=Label(win,text=" RCBs -")
    bl5.place(x=20,y=300)
    b5=Entry()
    b5.place(x=180,y=300,width=40,height=30)
    
    bl6=Label(win,text=" Platelets -")
    bl6.place(x=20,y=350)
    b6=Entry()
    b6.place(x=180,y=350,width=40,height=30)
    
    bl7=Label(win,text=" Vitamins D-")
    bl7.place(x=20,y=400)
    
    n=n1+n2+n3+n4+n5+n6
    b7=Entry()
    b7.place(x=180,y=400,width=40,height=30)
    
    '''
    btn7=Button(win,text="> Submit <",bg="blue4",fg="grey70",font="Helvetica",bd=5,command=new_window)
    btn7.place(x=80,y=450,width=110,height=30)
    '''
    
    #Your_profile
    img2 = Image.open("profile.png")
    bk1= ImageTk.PhotoImage(img2)
    lbl_img1 = Label(image=bk1,bg="snow3",bd=3)
    lbl_img1.image = bk1
    lbl_img1.place(x=370,y=100)
    btn1=Button(win,text="Your Profile",bg="goldenrod3",fg="black",font=("Helvetica") ,bd=5,command=your_profile)
    btn1.place(x=370,y=270,width=150,height=50)

    #book2
    img3 = Image.open("record.jpg")
    bk2= ImageTk.PhotoImage(img3)
    lbl_img2 = Label(image=bk2,bg="snow3",bd=3)
    lbl_img2.image = bk2
    lbl_img2.place(x=700,y=100)
    btn2=Button(win,text="Medical Records",bg="goldenrod3",fg="black",font=("Helvetica") ,bd=5,command=Book2)
    btn2.place(x=700,y=270,width=170,height=50)
    
    #book3
    img4 = Image.open("search.png")
    bk3= ImageTk.PhotoImage(img4)
    lbl_img3 = Label(image=bk3,bg="snow3",bd=3)
    lbl_img3.image = bk3
    lbl_img3.place(x=1050,y=100)
    btn3=Button(win,text="Search a Doner",bg="goldenrod3",fg="black",font=("Helvetica") ,bd=5,command=Book3)
    btn3.place(x=1050,y=270,width=160,height=50)
    
    #book4
    img5 = Image.open("request.jpg")
    bk4= ImageTk.PhotoImage(img5)
    lbl_img4 = Label(image=bk4,bg="snow3",bd=3)
    lbl_img4.image = bk4
    lbl_img4.place(x=370,y=420)
    btn4=Button(win,text="Make a Request",bg="goldenrod3",fg="black",font=("Helvetica") ,bd=5,command=Book4)
    btn4.place(x=370,y=590,width=160,height=50)
    
    #book5
    img6 = Image.open("call.png")
    bk5= ImageTk.PhotoImage(img6)
    lbl_img5 = Label(image=bk5,bg="snow3",bd=3)
    lbl_img5.image = bk5
    lbl_img5.place(x=700,y=420)
    btn5=Button(win,text="Call an Expert",bg="goldenrod3",fg="black",font=("Helvetica") ,bd=5,command=Book5)
    btn5.place(x=700,y=590,width=150,height=50)
    
    #book6
    img7 = Image.open("log.jpg")
    bk6= ImageTk.PhotoImage(img7)
    lbl_img6 = Label(image=bk6,bg="snow3",bd=3)
    lbl_img6.image = bk6
    lbl_img6.place(x=1050,y=420)
    btn6=Button(win,text="Log Out",bg="goldenrod3",fg="black",font=("Helvetica") ,bd=5,command=win.destroy)
    btn6.place(x=1050,y=590,width=120,height=50)

    
#opening screen
frame1=Frame(win,bg="lavender",bd=7)
frame1.place(x=0,y=0,width=1450,height=750)

#Login button
button1=Button(win,text="Admin",bg="maroon", fg="white",font=("Helvetica",16) ,bd=5,command=admin)
button1.place(x=550,y=450,width=120,height=30)

#Login button
button2=Button(win,text="User",bg="maroon", fg="white",font=("Helvetica",16) ,bd=5,command=main)
button2.place(x=825,y=450,width=120,height=30)

#title
frame1=Frame(win,bg="black",bd=7)
frame1.place(x=460,y=10,width=540,height=70)
label1=Label(win,text="Welcome to Heal Hands",relief=SUNKEN, fg="black", font=("Times",22) ,bg="yellow")
label1.place(x=480,y=20,width=500,height=50)

#inserting image
img1 = Image.open("Picture1a.png")
img = ImageTk.PhotoImage(img1)
lbl_img = Label(image=img)
lbl_img.image = img
lbl_img.place(x=550,y=100)


#close connection
conn.close()

win.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\dewas\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: __init__() missing 1 required positional argument: 'master'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\dewas\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: __init__() missing 1 required positional argument: 'master'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\dewas\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: __init__() missing 1 required positional argument: 'master'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\dewas\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# ...
